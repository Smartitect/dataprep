# %%
# Import all of the libraries we need to use...
import pandas as pd
import azureml.dataprep as dprep
import os as os
import re as re
import collections
import seaborn as sns
from azureml.dataprep import value
from azureml.dataprep import col
from azureml.dataprep import Dataflow
from commonCode import savePackage, openPackage, createFullPackagePath

# %%
dataFlow = Dataflow.open('./packages/PEOPLE_3_A_package.dprep')

# %%
df = dataFlow.to_pandas_dataframe()

# %%
dataProfile = dataFlow.get_profile()

# %%
dataProfile
# Out:
# ColumnProfile:
#     column_name: ADDRESS
#     type: FieldType.STRING
#
#     min: 'highfields\0d0aNordham\0d0aNorth Cave\0d0aNorth Humberside
#     max: wind Farm Cottage \0d0a62 Hollow Garden \0d0aMosborough \0d0aSheffield
#     count: 19147.0
#     missing_count: 29.0
#     not_missing_count: 19118.0
#     percent_missing: 0.0015145975870893612
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: AGECERT
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 19147.0
#     missing_count: 1.0
#     not_missing_count: 19146.0
#     percent_missing: 5.222750300308142e-05
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: ARI
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 1.0
#     count: 19147.0
#     missing_count: 305.0
#     not_missing_count: 18842.0
#     percent_missing: 0.015929388415939834
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 0.0
#           99%: 0.0
#         99.9%: 0.0
#
#     mean: 0.00010614584439019137
#     std: 0.010302437120460906
#     variance: 0.00010614021062105082
#     skewness: 97.03865551098278
#     kurtosis: 9415.000344968419
#
# ColumnProfile:
#     column_name: DATEDIED
#     type: FieldType.DATE
#
#     min: 1979-06-05 00:00:00+00:00
#     max: 2007-06-12 00:00:00+00:00
#     count: 19147.0
#     missing_count: 18377.0
#     not_missing_count: 770.0
#     percent_missing: 0.9597848226876273
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: DOB
#     type: FieldType.DATE
#
#     min: 1900-01-01 00:00:00+00:00
#     max: 2008-10-25 00:00:00+00:00
#     count: 19147.0
#     missing_count: 1.0
#     not_missing_count: 19146.0
#     percent_missing: 5.222750300308142e-05
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: FORENAME
#     type: FieldType.STRING
#
#     min: A
#     max: trefor
#     count: 19147.0
#     missing_count: 8373.0
#     not_missing_count: 10774.0
#     percent_missing: 0.43730088264480077
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: GENEMAIL
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: GENPHONE
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: GENPOSTAL
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: GENSMS
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: GMPDATE
#     type: FieldType.DATE
#
#     min: 1955-12-04 00:00:00+00:00
#     max: 2071-07-03 00:00:00+00:00
#     count: 19147.0
#     missing_count: 183.0
#     not_missing_count: 18964.0
#     percent_missing: 0.009557633049563901
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: ID
#     type: FieldType.INTEGER
#
#     min: 17936.0
#     max: 36765.0
#     count: 19147.0
#     missing_count: 1.0
#     not_missing_count: 19146.0
#     percent_missing: 5.222750300308142e-05
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 17957.505076923077
#            1%: 19834.11288011696
#            5%: 19741.04861111111
#           25%: 22621.57794636583
#           50%: 27301.880255872522
#           75%: 31965.093154567367
#           95%: 35743.97104916763
#           99%: 36546.678301158296
#         99.9%: 36743.43258133971
#
#     mean: 27298.755562519484
#     std: 5400.796882343092
#     variance: 29168606.964326866
#     skewness: 0.007268103979632813
#     kurtosis: -1.194865681433907
#
# ColumnProfile:
#     column_name: INITIALS
#     type: FieldType.STRING
#
#     min: A
#     max: ZR
#     count: 19147.0
#     missing_count: 32.0
#     not_missing_count: 19115.0
#     percent_missing: 0.0016712800960986054
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: MARRCERT
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 19147.0
#     missing_count: 108.0
#     not_missing_count: 19039.0
#     percent_missing: 0.005640570324332793
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: MARRDATE
#     type: FieldType.DATE
#
#     min: 1937-08-19 00:00:00+00:00
#     max: 2006-08-25 00:00:00+00:00
#     count: 19147.0
#     missing_count: 18944.0
#     not_missing_count: 203.0
#     percent_missing: 0.9893978168903744
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: MEMNO
#     type: FieldType.INTEGER
#
#     min: -1.0
#     max: 75557.0
#     count: 19147.0
#     missing_count: 93.0
#     not_missing_count: 19054.0
#     percent_missing: 0.004857157779286573
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -1.0
#            1%: -1.0
#            5%: -1.0
#           25%: -1.0
#           50%: -1.0
#           75%: 24914.625957164757
#           95%: 35739.70200524326
#           99%: 75115.53391774754
#         99.9%: 75470.72077033493
#
#     mean: 12435.812637766383
#     std: 16403.078870793048
#     variance: 269060996.4414573
#     skewness: 1.3776211280811366
#     kurtosis: 2.4278152117282525
#
# ColumnProfile:
#     column_name: MINRETIREMENTDATE
#     type: FieldType.STRING
#
#     min: 02/03/2020
#     max: 27/01/2011
#     count: 19147.0
#     missing_count: 19141.0
#     not_missing_count: 6.0
#     percent_missing: 0.9996866349819815
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: MSTA
#     type: FieldType.STRING
#
#     min: 0
#     max: Widowed
#     count: 19147.0
#     missing_count: 1.0
#     not_missing_count: 19146.0
#     percent_missing: 5.222750300308142e-05
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: NINO
#     type: FieldType.STRING
#
#     min: 19473
#     max: ZZ019055Y
#     count: 19147.0
#     missing_count: 5.0
#     not_missing_count: 19142.0
#     percent_missing: 0.0002611375150154071
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: OTHERNO
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 19147.0
#     missing_count: 519.0
#     not_missing_count: 18628.0
#     percent_missing: 0.027106074058599258
#     error_count: 173.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: OVERSEAS
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 19147.0
#     missing_count: 11052.0
#     not_missing_count: 8095.0
#     percent_missing: 0.5772183631900559
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: PENSERYEARS
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: POSTCODE
#     type: FieldType.STRING
#
#     min: A10 1BI
#     max: ZZ96 6LP
#     count: 19147.0
#     missing_count: 1.0
#     not_missing_count: 19146.0
#     percent_missing: 5.222750300308142e-05
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: PROTECTIONAMT
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 0.0
#     count: 19147.0
#     missing_count: 11130.0
#     not_missing_count: 8017.0
#     percent_missing: 0.5812921084242962
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 0.0
#           99%: 0.0
#         99.9%: 0.0
#
#     mean: 0.0
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile:
#     column_name: PROTECTIONTYPE
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: PROTECTPCENT
#     type: FieldType.INTEGER
#
#     min: 0.0
#     max: 0.0
#     count: 19147.0
#     missing_count: 11130.0
#     not_missing_count: 8017.0
#     percent_missing: 0.5812921084242962
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 0.0
#            1%: 0.0
#            5%: 0.0
#           25%: 0.0
#           50%: 0.0
#           75%: 0.0
#           95%: 0.0
#           99%: 0.0
#         99.9%: 0.0
#
#     mean: 0.0
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile:
#     column_name: PSFLAG
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: PSPART
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: QUOEMAIL
#     type: FieldType.STRING
#
#     min: Y
#     max: Y
#     count: 19147.0
#     missing_count: 19145.0
#     not_missing_count: 2.0
#     percent_missing: 0.9998955449939938
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: QUOPHONE
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: QUOPOSTAL
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: QUOSMS
#     type: FieldType.STRING
#
#     min: None
#     max: None
#     count: 19147.0
#     missing_count: 19147.0
#     not_missing_count: 0.0
#     percent_missing: 1.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: REGCHECKED
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: False
#     count: 19147.0
#     missing_count: 11130.0
#     not_missing_count: 8017.0
#     percent_missing: 0.5812921084242962
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: REGISTRATION
#     type: FieldType.STRING
#
#     min: 100th NRA 60
#     max: phillipa
#     count: 19147.0
#     missing_count: 12151.0
#     not_missing_count: 6996.0
#     percent_missing: 0.6346163889904424
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: SEX
#     type: FieldType.STRING
#
#     min: F
#     max: M
#     count: 19147.0
#     missing_count: 1.0
#     not_missing_count: 19146.0
#     percent_missing: 5.222750300308142e-05
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: SPAD
#     type: FieldType.DATE
#
#     min: 1955-12-04 00:00:00+00:00
#     max: 2066-07-24 00:00:00+00:00
#     count: 19147.0
#     missing_count: 310.0
#     not_missing_count: 18837.0
#     percent_missing: 0.01619052593095524
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: SURNAME
#     type: FieldType.STRING
#
#     min: SurnameA
#     max: SurnameZ
#     count: 19147.0
#     missing_count: 1.0
#     not_missing_count: 19146.0
#     percent_missing: 5.222750300308142e-05
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: TITLE
#     type: FieldType.STRING
#
#     min: Doct
#     max: mrs
#     count: 19147.0
#     missing_count: 3.0
#     not_missing_count: 19144.0
#     percent_missing: 0.00015668250900924426
#     error_count: 0.0
#     empty_count: 0.0

# %%
dateOfBirth = df[['ID','DOB']]

# %%
profileReport = pp.ProfileReport(dateOfBirth, check_correlation = True)
profileReport.to_file('./profileReport.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6525ab5b4de1> in <module>
# ----> 1 profileReport = pp.ProfileReport(dateOfBirth, check_correlation = True)
#       2 profileReport.to_file('./profileReport.html')
#
# NameError: name 'pp' is not defined

# %%
dateOfBirth['DOB'] = pd.to_datetime(dateOfBirth['DOB'])
# Out:
# C:\Users\bsmart\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
dateOfBirth['Year'] = dateOfBirth['DOB'].dt.year
dateOfBirth['Month'] = dateOfBirth['DOB'].dt.month
dateOfBirth['Day'] = dateOfBirth['DOB'].dt.day
dateOfBirth['WeekDay'] = dateOfBirth['DOB'].dt.dayofweek
# Out:
# C:\Users\bsmart\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\bsmart\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\bsmart\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\bsmart\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
dateOfBirth
# Out:
#             ID        DOB    Year  Month   Day  WeekDay
# 0      18373.0 1913-04-03  1913.0    4.0   3.0      3.0
# 1      18375.0 1924-12-17  1924.0   12.0  17.0      2.0
# 2      18376.0 1925-08-04  1925.0    8.0   4.0      1.0
# 3      18377.0 1925-05-11  1925.0    5.0  11.0      0.0
# 4      18378.0 1922-10-19  1922.0   10.0  19.0      3.0
# 5      18379.0 1924-12-17  1924.0   12.0  17.0      2.0
# 6      18380.0 1924-04-02  1924.0    4.0   2.0      2.0
# 7      18381.0 1925-10-20  1925.0   10.0  20.0      1.0
# 8      18382.0 1925-07-01  1925.0    7.0   1.0      2.0
# 9      18383.0 1925-10-09  1925.0   10.0   9.0      4.0
# 10     18384.0 1924-03-20  1924.0    3.0  20.0      3.0
# 11     18385.0 1913-12-09  1913.0   12.0   9.0      1.0
# 12     18385.0 1913-12-09  1913.0   12.0   9.0      1.0
# 13     18386.0 1921-04-26  1921.0    4.0  26.0      1.0
# 14     18387.0 1926-02-26  1926.0    2.0  26.0      4.0
# 15     18389.0 1926-09-01  1926.0    9.0   1.0      2.0
# 16     18390.0 1926-09-20  1926.0    9.0  20.0      0.0
# 17     18391.0 1926-09-10  1926.0    9.0  10.0      4.0
# 18     18392.0 1926-08-05  1926.0    8.0   5.0      3.0
# 19     18393.0 1926-07-21  1926.0    7.0  21.0      2.0
# 20     18394.0 1926-06-10  1926.0    6.0  10.0      3.0
# 21     18394.0 1926-06-10  1926.0    6.0  10.0      3.0
# 22     18394.0 1926-06-10  1926.0    6.0  10.0      3.0
# 23     18395.0 1927-01-16  1927.0    1.0  16.0      6.0
# 24     18396.0 1916-11-16  1916.0   11.0  16.0      3.0
# 25     18397.0 1963-05-13  1963.0    5.0  13.0      0.0
# 26     18398.0 1929-07-17  1929.0    7.0  17.0      2.0
# 27     18399.0 1914-06-01  1914.0    6.0   1.0      0.0
# 28     18400.0 1926-05-31  1926.0    5.0  31.0      0.0
# 29     18401.0 1927-10-10  1927.0   10.0  10.0      0.0
# ...        ...        ...     ...    ...   ...      ...
# 19117  36731.0 1961-07-14  1961.0    7.0  14.0      4.0
# 19118  36732.0 1929-11-20  1929.0   11.0  20.0      2.0
# 19119  36733.0 2002-02-10  2002.0    2.0  10.0      6.0
# 19120  36734.0 2008-10-25  2008.0   10.0  25.0      5.0
# 19121  36735.0 1946-11-09  1946.0   11.0   9.0      5.0
# 19122  36736.0 1966-04-12  1966.0    4.0  12.0      1.0
# 19123  36737.0 2002-02-10  2002.0    2.0  10.0      6.0
# 19124  36740.0 1936-06-14  1936.0    6.0  14.0      6.0
# 19125  36741.0 1952-02-26  1952.0    2.0  26.0      1.0
# 19126  36742.0 1944-02-17  1944.0    2.0  17.0      3.0
# 19127  36743.0 1971-08-22  1971.0    8.0  22.0      6.0
# 19128  36744.0 2004-08-04  2004.0    8.0   4.0      2.0
# 19129  36745.0 2004-08-04  2004.0    8.0   4.0      2.0
# 19130  36746.0 2005-12-05  2005.0   12.0   5.0      0.0
# 19131  36748.0 1966-12-14  1966.0   12.0  14.0      2.0
# 19132  36750.0 1949-09-14  1949.0    9.0  14.0      2.0
# 19133  36751.0 1958-02-25  1958.0    2.0  25.0      1.0
# 19134  36752.0 1945-10-17  1945.0   10.0  17.0      2.0
# 19135  36753.0 1944-12-20  1944.0   12.0  20.0      2.0
# 19136  36754.0 1943-11-21  1943.0   11.0  21.0      6.0
# 19137  36755.0 2000-04-26  2000.0    4.0  26.0      2.0
# 19138  36756.0 1943-01-24  1943.0    1.0  24.0      6.0
# 19139  36757.0 1943-03-27  1943.0    3.0  27.0      5.0
# 19140  36759.0 1960-08-10  1960.0    8.0  10.0      2.0
# 19141  36760.0 1932-08-27  1932.0    8.0  27.0      5.0
# 19142  36761.0 1971-04-29  1971.0    4.0  29.0      3.0
# 19143  36762.0 2001-01-20  2001.0    1.0  20.0      5.0
# 19144  36763.0 1927-11-10  1927.0   11.0  10.0      3.0
# 19145  36764.0 1960-05-07  1960.0    5.0   7.0      5.0
# 19146  36765.0 1933-05-22  1933.0    5.0  22.0      0.0
#
# [19147 rows x 6 columns]

# %%
dateOfBirth.dtypes
# Out:
# ID                float64
# DOB        datetime64[ns]
# Year              float64
# Month             float64
# Day               float64
# WeekDay           float64
# dtype: object

# %%
plot = sns.countplot(x="Year", data=dateOfBirth)

# %%
plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3f836e597baf> in <module>()
# ----> 1 plot
#
# NameError: name 'plot' is not defined
